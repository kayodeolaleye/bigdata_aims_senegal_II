# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Principal Component Analysis

# %%
x = np.random.normal(0.0,3.5,501)
y = np.random.normal(0.0,0.5,501)
theta = -(np.pi/6.0)
x2 = x*np.cos(theta) + y*np.sin(theta)
y2 = y*np.cos(theta) + x*np.sin(theta)

# %%
plt.figure(figsize=(12,7))
plt.scatter(x2,y2)

plt.axis('scaled')
# Out:
# (-15.0, 15.0, -8.0, 6.0)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(np.c_[x2,y2])
# Out:
# PCA(copy=True, n_components=2, whiten=False)

# %%
pca.components_
# Out:
# array([[-0.86411991,  0.50328599],
#        [-0.50328599, -0.86411991]])

# %%
vector = pca.components_

# %%
# plt.figure(figsize=(12,7))
plt.scatter(x2,y2)
plt.quiver(np.mean(x2),np.mean(y2), vector[0][0], vector[0][1], angles='xy',scale=5.0,color='r')
plt.quiver(np.mean(x2),np.mean(y2), vector[1][0], vector[1][1], angles='xy',scale=10.0,color='r')
plt.axis('scaled')
# Out:
# (-15.0, 15.0, -8.0, 6.0)

# %%
pca.explained_variance_ratio_ #98% of the variance is along the principal component axis
# Out:
# array([ 0.99435209,  0.00564791])

# %%
pca.get_covariance()
# Out:
# array([[ 8.56919189, -4.95302932],
#        [-4.95302932,  2.9498319 ]])

# %%
X=pca.fit_transform(np.c_[x2,y2])

# %%
plt.scatter(X.T[0],X.T[1])
plt.axis('scaled')
# Out:
# (-15.0, 15.0, -0.80000000000000004, 0.80000000000000004)
